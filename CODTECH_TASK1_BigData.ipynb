# %%
CODTECH_TASK_BigData.ipynb

# %%
# !pip install pyspark

# %%
from pyspark.sql import SparkSession

# Create Spark session
spark = SparkSession.builder \
    .appName("Big Data Analysis Task") \
    .getOrCreate()

print("Spark Session Created Successfully!")
# Out:
# Spark Session Created Successfully!

# %%
import random

data = []

categories = ["Electronics", "Clothing", "Groceries", "Books"]

for i in range(100000):   # 1 lakh rows
    record = (
        i,
        random.choice(categories),
        random.randint(100, 5000)
    )
    data.append(record)

columns = ["Transaction_ID", "Category", "Amount"]

df = spark.createDataFrame(data, columns)

df.show(5)
# Out:
# +--------------+-----------+------+
# |Transaction_ID|   Category|Amount|
# +--------------+-----------+------+
# |             0|   Clothing|  3101|
# |             1|Electronics|  4742|
# |             2|Electronics|  4489|
# |             3|  Groceries|  4697|
# |             4|Electronics|  2542|
# +--------------+-----------+------+
# only showing top 5 rows

# %%
print("Total Records:", df.count())
# Out:
# Total Records: 100000

# %%
df.describe().show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_515/722689003.py in <cell line: 0>()
# ----> 1 df.describe().show()
#
# NameError: name 'df' is not defined

# %%
import pyspark

# %%
from pyspark.sql import SparkSession

# Create Spark session
spark = SparkSession.builder \
    .appName("Big Data Analysis Task") \
    .getOrCreate()

print("Spark Session Created Successfully!")
# Out:
# Spark Session Created Successfully!

# %%
import random

data = []

categories = ["Electronics", "Clothing", "Groceries", "Books"]

for i in range(100000):   # 1 lakh rows
    record = (
        i,
        random.choice(categories),
        random.randint(100, 5000)
    )
    data.append(record)

columns = ["Transaction_ID", "Category", "Amount"]

df = spark.createDataFrame(data, columns)

df.show(5)
# Out:
# +--------------+-----------+------+
# |Transaction_ID|   Category|Amount|
# +--------------+-----------+------+
# |             0|  Groceries|  2861|
# |             1|   Clothing|   746|
# |             2|  Groceries|  4621|
# |             3|Electronics|  1543|
# |             4|   Clothing|   197|
# +--------------+-----------+------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import avg

df.groupBy("Category").agg(avg("Amount")).show()
# Out:
# +-----------+------------------+
# |   Category|       avg(Amount)|
# +-----------+------------------+
# |  Groceries| 2542.936144770408|
# |Electronics|        2552.82444|
# |   Clothing|2559.7298730515827|
# |      Books|  2554.79276578737|
# +-----------+------------------+

# %%
df.describe().show()
# Out:
# +-------+-----------------+---------+------------------+
# |summary|   Transaction_ID| Category|            Amount|
# +-------+-----------------+---------+------------------+
# |  count|           100000|   100000|            100000|
# |   mean|          49999.5|     NULL|        2552.55504|
# | stddev|28867.65779668774|     NULL|1415.6696116238033|
# |    min|                0|    Books|               100|
# |    max|            99999|Groceries|              5000|
# +-------+-----------------+---------+------------------+
